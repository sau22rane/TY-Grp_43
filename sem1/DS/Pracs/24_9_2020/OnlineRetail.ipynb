# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("OnlineRetail.csv")

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
items = []
m = 0
lena = []
group = df.groupby('InvoiceNo')
for i,j in group:
    lena.append(len(j["Description"]))
    if(len(j["Description"])>400):
        continue
    temp = []
    for l in j["Description"]:
        temp.append(l)
    items.append(temp)
    if(len(j["Description"])>400):
        m+=1
print(len(items),m)
# Out:
# 25819 0

# %%
print(items[-5:])

# %%
#a = np.array(items)
df = pd.DataFrame(items)
len(df)
# Out:
#       0                                   1                            2    \
# 0  536365  WHITE HANGING HEART T-LIGHT HOLDER          WHITE METAL LANTERN
# 1  536366              HAND WARMER UNION JACK    HAND WARMER RED POLKA DOT
# 2  536367       ASSORTED COLOUR BIRD ORNAMENT   POPPY'S PLAYHOUSE BEDROOM
# 3  536368            JAM MAKING SET WITH JARS  RED COAT RACK PARIS FASHION
# 4  536369            BATH BUILDING BLOCK WORD                         None
#
#                               3                                    4    \
# 0  CREAM CUPID HEARTS COAT HANGER  KNITTED UNION FLAG HOT WATER BOTTLE
# 1                            None                                 None
# 2       POPPY'S PLAYHOUSE KITCHEN    FELTCRAFT PRINCESS CHARLOTTE DOLL
# 3  YELLOW COAT RACK PARIS FASHION         BLUE COAT RACK PARIS FASHION
# 4                            None                                 None
#
#                               5                                   6    \
# ...

# %%
df.to_csv("temp.csv")

# %%
len(df)
# Out:
# 25819

# %%
df2 = pd.read_csv("temp.csv", header = None)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,
# ...

# %%
df2.head()
# Out:
#                                   0                            1    \
# 0  WHITE HANGING HEART T-LIGHT HOLDER          WHITE METAL LANTERN
# 1              HAND WARMER UNION JACK    HAND WARMER RED POLKA DOT
# 2       ASSORTED COLOUR BIRD ORNAMENT   POPPY'S PLAYHOUSE BEDROOM
# 3            JAM MAKING SET WITH JARS  RED COAT RACK PARIS FASHION
# 4            BATH BUILDING BLOCK WORD                          NaN
#
#                               2                                    3    \
# 0  CREAM CUPID HEARTS COAT HANGER  KNITTED UNION FLAG HOT WATER BOTTLE
# 1                             NaN                                  NaN
# 2       POPPY'S PLAYHOUSE KITCHEN    FELTCRAFT PRINCESS CHARLOTTE DOLL
# 3  YELLOW COAT RACK PARIS FASHION         BLUE COAT RACK PARIS FASHION
# 4                             NaN                                  NaN
#
#                               4                                   5    \
# ...

# %%
# from apyori import apriori
# rules = apriori(transactions = transactions, min_support = 0.003,
# min_confidence = 0.2, min_lift = 4, min_length = 2, max_length =
# 3)
# """# Visualising the results
# ## Displaying the first results coming directly from the output
# of the apriori function
# """
# results = list(rules)
# print("There are {} RULES derived.".format(len(results)))
# results
# for i in range(0, len(results)):
# print(results[i][0])
# # first index of the inner list
# for item in results :
# pair=item[0]
# #print(pair)
# items=[x for x in pair]
# #print (items)
# print(items[0]+'->'+items[1])
# # second index of the inner list
# print("Support: " + str(item[1]))
# # third index of the list located a
# print("Confidence: " + str(item[2][0][2]))
# print("Lift: " + str(item[2][0][3]))
# print("===============================")
# def inspect(results):
# lhs
# = [tuple(result[2][0][0])[0] for result in
# results]
# rhs
# = [tuple(result[2][0][1])[0] for result in
# results]
# supports
# = [result[1] for result in results]
# confidences = [result[2][0][2] for result in results]
# lifts
# = [result[2][0][3] for result in results]
# return list(zip(lhs, rhs, supports, confidences, lifts))
# resultsinDataFrame = pd.DataFrame(inspect(results), columns =
# ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence',
# 'Lift'])
# """## Displaying the results non sorted"""
# resultsinDataFrame
# """## Displaying the results sorted by descending lifts"""
# resultsinDataFrame.nlargest(n = 5, columns = 'Lift')

# %%
# from apyori import apriori
# rules = apriori(transactions = df2, min_support = 0.001,
#                 min_confidence = 0.8)
# results = list(rules)

# %%
transactions = []
for i in range(0, 2000):
    transactions.append([str(df2.values[i,j]) for j in range(0,30)])
transactions[0]
# Out:
# ['WHITE HANGING HEART T-LIGHT HOLDER',
#  'WHITE METAL LANTERN',
#  'CREAM CUPID HEARTS COAT HANGER',
#  'KNITTED UNION FLAG HOT WATER BOTTLE',
#  'RED WOOLLY HOTTIE WHITE HEART.',
#  'SET 7 BABUSHKA NESTING BOXES',
#  'GLASS STAR FROSTED T-LIGHT HOLDER',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan']

# %%
print(transactions[0])
# Out:
# ['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'GLASS STAR FROSTED T-LIGHT HOLDER', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']

# %%
from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.001,
                min_confidence = 0.8, min_lift = 4, min_length = 2, max_length = 3)
results = list(rules)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-4cd2bb4f03ef> in <module>
#       2 rules = apriori(transactions = transactions, min_support = 0.001,
#       3                 min_confidence = 0.8, min_lift = 4, min_length = 2, max_length = 3)
# ----> 4 results = list(rules)
#
# ~/.local/lib/python3.6/site-packages/apyori.py in apriori(transactions, **kwargs)
#     284
#     285     # Calculate ordered stats.
# --> 286     for support_record in support_records:
#     287         ordered_statistics = list(
#     288             _filter_ordered_statistics(
#
# ~/.local/lib/python3.6/site-packages/apyori.py in gen_support_records(transaction_manager, min_support, **kwargs)
#     197         if max_length and length > max_length:
#     198             break
# --> 199         candidates = _create_next_candidates(relations, length)
#     200
#     201
#
# ...
