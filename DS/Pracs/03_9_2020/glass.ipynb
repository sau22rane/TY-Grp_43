# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b478a6fd18e5> in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data = pd.read_csv("glass.csv")

# %%
data.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
print(len(data.columns))
# Out:
# 10

# %%
data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
data.head(7)
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.00     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00     1
# 5  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26     1
# 6  1.51743  13.30  3.60  1.14  73.09  0.58  8.17  0.0  0.00     1

# %%
data.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516523   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
data.Type.unique()
# Out:
# array([1, 2, 3, 5, 6, 7])

# %%
grouped = data.groupby('Type')
for col,group in grouped:
    print(col)
    print(group)
# Out:
# 1
#          RI     Na    Mg    Al     Si     K     Ca   Ba    Fe  Type
# 0   1.52101  13.64  4.49  1.10  71.78  0.06   8.75  0.0  0.00     1
# 1   1.51761  13.89  3.60  1.36  72.73  0.48   7.83  0.0  0.00     1
# 2   1.51618  13.53  3.55  1.54  72.99  0.39   7.78  0.0  0.00     1
# 3   1.51766  13.21  3.69  1.29  72.61  0.57   8.22  0.0  0.00     1
# 4   1.51742  13.27  3.62  1.24  73.08  0.55   8.07  0.0  0.00     1
# ..      ...    ...   ...   ...    ...   ...    ...  ...   ...   ...
# 65  1.52099  13.69  3.59  1.12  71.96  0.09   9.40  0.0  0.00     1
# 66  1.52152  13.05  3.65  0.87  72.22  0.19   9.85  0.0  0.17     1
# 67  1.52152  13.05  3.65  0.87  72.32  0.19   9.85  0.0  0.17     1
# 68  1.52152  13.12  3.58  0.90  72.20  0.23   9.82  0.0  0.16     1
# 69  1.52300  13.31  3.58  0.82  71.99  0.12  10.17  0.0  0.03     1
#
# [70 rows x 10 columns]
# 2
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Type
# ...

# %%
for group in grouped:
    print(group[0])
    print(group[1].agg([np.sum, np.mean, np.std]),end = '\n\n\n')
# Out:
# 1
#               RI          Na          Mg         Al           Si          K  \
# sum   106.310280  926.960000  248.670000  81.470000  5083.340000  31.320000
# mean    1.518718   13.242286    3.552429   1.163857    72.619143   0.447429
# std     0.002268    0.499301    0.247043   0.273158     0.569484   0.214879
#
#               Ca        Ba        Fe  Type
# sum   615.810000  0.890000  3.990000  70.0
# mean    8.797286  0.012714  0.057000   1.0
# std     0.574807  0.083838  0.089075   0.0
#
#
# 2
#               RI          Na          Mg          Al           Si          K  \
# sum   115.415010  996.490000  228.160000  107.020000  5517.450000  39.600000
# mean    1.518619   13.111711    3.002105    1.408158    72.598026   0.521053
# std     0.003802    0.664159    1.215661    0.318340     0.724573   0.213726
#
#               Ca        Ba        Fe   Type
# sum   689.600000  3.820000  6.060000  152.0
# mean    9.073684  0.050263  0.079737    2.0
# ...

# %%
data.sort_values(['Type', 'Ca', 'Mg', 'Na'],ascending=[True, False, False, False]).head()
# Out:
#          RI     Na    Mg    Al     Si     K     Ca   Ba    Fe  Type
# 69  1.52300  13.31  3.58  0.82  71.99  0.12  10.17  0.0  0.03     1
# 50  1.52320  13.72  3.72  0.51  71.75  0.09  10.06  0.0  0.16     1
# 48  1.52223  13.21  3.77  0.79  71.99  0.13  10.02  0.0  0.00     1
# 66  1.52152  13.05  3.65  0.87  72.22  0.19   9.85  0.0  0.17     1
# 67  1.52152  13.05  3.65  0.87  72.32  0.19   9.85  0.0  0.17     1

# %%
data = data[['Ca', 'Mg', 'Na', 'Si', 'K', 'Al', 'RI', 'Ba', 'Fe', 'Type']]
data.head()
# Out:
#      Ca    Mg     Na     Si     K    Al       RI   Ba   Fe  Type
# 0  8.75  4.49  13.64  71.78  0.06  1.10  1.52101  0.0  0.0     1
# 1  7.83  3.60  13.89  72.73  0.48  1.36  1.51761  0.0  0.0     1
# 2  7.78  3.55  13.53  72.99  0.39  1.54  1.51618  0.0  0.0     1
# 3  8.22  3.69  13.21  72.61  0.57  1.29  1.51766  0.0  0.0     1
# 4  8.07  3.62  13.27  73.08  0.55  1.24  1.51742  0.0  0.0     1

# %%
data.describe()
# Out:
#                Ca          Mg          Na          Si           K          Al  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    2.684533   13.407850   72.650935    0.497056    1.444907
# std      1.423153    1.442408    0.816604    0.774546    0.652192    0.499270
# min      5.430000    0.000000   10.730000   69.810000    0.000000    0.290000
# 25%      8.240000    2.115000   12.907500   72.280000    0.122500    1.190000
# 50%      8.600000    3.480000   13.300000   72.790000    0.555000    1.360000
# 75%      9.172500    3.600000   13.825000   73.087500    0.610000    1.630000
# max     16.190000    4.490000   17.380000   75.410000    6.210000    3.500000
#
#                RI          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     1.518365    0.175047    0.057009    2.780374
# std      0.003037    0.497219    0.097439    2.103739
# ...

# %%
grouped = data.groupby('Type')
for group in grouped:
    print(group[0])
    print(group[1].agg([np.mean, np.std]),end = '\n\n\n')
# Out:
# 1
#             Ca        Mg         Na         Si         K        Al        RI  \
# mean  8.797286  3.552429  13.242286  72.619143  0.447429  1.163857  1.518718
# std   0.574807  0.247043   0.499301   0.569484  0.214879  0.273158  0.002268
#
#             Ba        Fe  Type
# mean  0.012714  0.057000   1.0
# std   0.083838  0.089075   0.0
#
#
# 2
#             Ca        Mg         Na         Si         K        Al        RI  \
# mean  9.073684  3.002105  13.111711  72.598026  0.521053  1.408158  1.518619
# std   1.921635  1.215661   0.664159   0.724573  0.213726  0.318340  0.003802
#
#             Ba        Fe  Type
# mean  0.050263  0.079737   2.0
# std   0.362340  0.106433   0.0
#
#
# 3
#             Ca        Mg         Na         Si         K        Al        RI  \
# mean  8.782941  3.543529  13.437059  72.404706  0.406471  1.201176  1.517964
# std   0.380111  0.162786   0.506887   0.512276  0.229890  0.347489  0.001916
#
#             Ba        Fe  Type
# ...

# %%
data.drop(["Si"], axis = 1, inplace = True)
data
# Out:
#        Ca    Mg     Na     K    Al       RI    Ba   Fe  Type
# 0    8.75  4.49  13.64  0.06  1.10  1.52101  0.00  0.0     1
# 1    7.83  3.60  13.89  0.48  1.36  1.51761  0.00  0.0     1
# 2    7.78  3.55  13.53  0.39  1.54  1.51618  0.00  0.0     1
# 3    8.22  3.69  13.21  0.57  1.29  1.51766  0.00  0.0     1
# 4    8.07  3.62  13.27  0.55  1.24  1.51742  0.00  0.0     1
# ..    ...   ...    ...   ...   ...      ...   ...  ...   ...
# 209  9.18  0.00  14.14  0.08  2.88  1.51623  1.06  0.0     7
# 210  8.40  0.00  14.92  0.00  1.99  1.51685  1.59  0.0     7
# 211  8.44  0.00  14.36  0.00  2.02  1.52065  1.64  0.0     7
# 212  8.48  0.00  14.38  0.00  1.94  1.51651  1.57  0.0     7
# 213  8.62  0.00  14.23  0.00  2.08  1.51711  1.67  0.0     7
#
# [214 rows x 9 columns]

# %%
data.head()
# Out:
#      Ca    Mg     Na     K    Al       RI   Ba   Fe  Type
# 0  8.75  4.49  13.64  0.06  1.10  1.52101  0.0  0.0     1
# 1  7.83  3.60  13.89  0.48  1.36  1.51761  0.0  0.0     1
# 2  7.78  3.55  13.53  0.39  1.54  1.51618  0.0  0.0     1
# 3  8.22  3.69  13.21  0.57  1.29  1.51766  0.0  0.0     1
# 4  8.07  3.62  13.27  0.55  1.24  1.51742  0.0  0.0     1

# %%
data.drop(data.index[[1,3]]).head()
# Out:
#      Ca    Mg     Na     K    Al       RI   Ba    Fe  Type
# 0  8.75  4.49  13.64  0.06  1.10  1.52101  0.0  0.00     1
# 2  7.78  3.55  13.53  0.39  1.54  1.51618  0.0  0.00     1
# 4  8.07  3.62  13.27  0.55  1.24  1.51742  0.0  0.00     1
# 5  8.07  3.61  12.79  0.64  1.62  1.51596  0.0  0.26     1
# 6  8.17  3.60  13.30  0.58  1.14  1.51743  0.0  0.00     1
