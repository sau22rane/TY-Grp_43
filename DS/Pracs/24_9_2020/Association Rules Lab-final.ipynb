# %% [markdown]
# ## APRIORI

# %%
import pandas as pd
import numpy as np
import math

# %%
df = pd.read_csv("OnlineRetail.csv")
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
len(df)
# Out:
# 532621

# %%
grps = df.groupby(['InvoiceNo','InvoiceDate'])
transactions = []
longest_count = 0
one,two,three,eight = 0,0,0,0
longest_invoice = 0
longest = []
for i,j in grps:
    if(longest_count<len(j)):
        longest_count = len(j)
        longest_invoice = i
        longest = list(j['Description'].map(str))
    if(len(j)==1):
        one+=1
    elif(len(j)==2):
        two+=1
    elif(len(j)==3):
        three+=1
    elif(len(j)==8):
        eight+=1
    transactions.append(list(j['Description'].map(str)))

# %% [markdown]
# #### Get a total number of transactions with 1 item, 2 items , 3 items and 8 items.

# %%
print("There are {} transactions with {} item(s).".format(one,"one"))
print("There are {} transactions with {} item(s).".format(two,"two"))
print("There are {} transactions with {} item(s).".format(three,"three"))
print("There are {} transactions with {} item(s).".format(eight,"eight"))
# Out:
# There are 3718 transactions with one item(s).
# There are 843 transactions with two item(s).
# There are 697 transactions with three item(s).
# There are 605 transactions with eight item(s).

# %% [markdown]
# #### Get the number of items in the longest transaction

# %%
print("Longest transaction \nInvoice number: {}\nDate: {}\nNumber of items: {}".format(longest_invoice[0],longest_invoice[1],longest_count))
# Out:
# Longest transaction
# Invoice number: 573585
# Date: 10/31/2011 14:41
# Number of items: 1114

# %%
print("Longest transaction items:")
print(longest)
# Out:
# Longest transaction items:
# ['ASSTD DESIGN RACING CAR PEN', 'ASSORTED COLOURS SILK FAN', 'SANDALWOOD FAN', 'EDWARDIAN PARASOL BLACK', 'EDWARDIAN PARASOL NATURAL', 'ICE CREAM DESIGN GARDEN PARASOL', 'FUNKY MONKEY GIFT BAG MEDIUM', 'HOUSE SHAPE PENCIL SHARPENER', 'RECYCLED PENCIL WITH RABBIT ERASER', 'KITTY PENCIL ERASERS', 'SLEEPING CAT ERASERS', 'PARTY TIME PENCIL ERASERS', 'BROCADE RING PURSE', 'ORIGAMI JASMINE INCENSE/CANDLE SET', 'ORIGAMI LAVENDER INCENSE/CANDL SET', 'ORIGAMI SANDLEWOOD INCENSE/CAND SET', 'BLUE GLASS GEMS IN BAG', 'WHITE TALL PORCELAIN T-LIGHT HOLDER', 'BLUE POLKADOT PASSPORT COVER', 'CHERRY BLOSSOM PASSPORT COVER', 'BLUE POLKADOT LUGGAGE TAG', 'FIRST CLASS LUGGAGE TAG', 'QUEEN OF SKIES LUGGAGE TAG', 'ECONOMY LUGGAGE TAG', 'RED RETROSPOT PURSE', 'DISCO BALL CHRISTMAS DECORATION', 'RED HEART LUGGAGE TAG', 'BLUE POLKADOT BOWL', 'EDWARDIAN PARASOL RED', 'DOORMAT RED RETROSPOT', "DOLLY MIXTURE CHILDREN'S UMBRELLA", 'FLORAL SOFT CAR TOY', 'JUMBO BAG TOYS', 'JUMBO BAG WOODLAND ANIMALS', 'JUMBO BAG OWLS', 'STRAWBERRY SHOPPER BAG', 'RED RETROSPOT SHOPPER BAG', 'WOODLAND CHARLOTTE BAG', 'STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'LUNCH BAG RED RETROSPOT', 'LUNCH BAG WOODLAND', 'LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE', 'GOLD MINI TAPE MEASURE', 'ASSORTED COLOUR MINI CASES', 'RED RETROSPOT MINI CASES', 'FUNKY WASHING UP GLOVES ASSORTED', 'DAISY NOTEBOOK', 'CHRYSANTHEMUM NOTEBOOK', 'SMALL BLUE PROVENCAL CERAMIC BALL', 'SILVER TEDDY BEAR', 'FRENCH PAISLEY CUSHION COVER', 'FRENCH FLORAL CUSHION COVER', 'ZINC HEART LATTICE T-LIGHT HOLDER', 'BLUE ROSE FABRIC MIRROR', 'SET/5 RED RETROSPOT LID GLASS BOWLS', 'PORCELAIN T-LIGHT HOLDERS ASSORTED', 'STRAWBERRY BATH SPONGE', 'APPLE BATH SPONGE', 'RED FLORAL FELTCRAFT SHOULDER BAG', 'PINK FLORAL FELTCRAFT SHOULDER BAG', 'PINK BLUE FELT CRAFT TRINKET BOX', 'PINK CREAM FELT CRAFT TRINKET BOX', '12 PENCIL SMALL TUBE WOODLAND', '36 PENCILS TUBE SKULLS', '36 PENCILS TUBE RED RETROSPOT', '12 PENCILS TALL TUBE SKULLS', '12 PENCILS TALL TUBE RED RETROSPOT', 'HEART CALCULATOR', 'ROSE DU SUD CUSHION COVER', 'ANTIQUE ALL GLASS CANDLESTICK', 'SWISS CHALET TREE DECORATION', 'DARK BIRD HOUSE TREE DECORATION', 'SET/2 RED RETROSPOT TEA TOWELS', 'TOOL BOX SOFT TOY', 'PARTY INVITES BALLOON GIRL', 'BOOM BOX SPEAKER BOYS', 'BOOM BOX SPEAKER GIRLS', 'VINTAGE BILLBOARD DRINK ME MUG', 'SET/20 RED RETROSPOT PAPER NAPKINS', 'SET/6 RED SPOTTY PAPER CUPS', 'SET/6 COLLAGE PAPER PLATES', 'SET/6 RED SPOTTY PAPER PLATES', 'CREAM SLICE FLANNEL PINK SPOT', 'OWL DOORSTOP', 'SET/10 IVORY POLKADOT PARTY CANDLES', 'SET 6 FOOTBALL CELEBRATION CANDLES', 'SET OF 6 GIRLS CELEBRATION CANDLES', 'GOLD STANDING GNOME', 'JINGLE BELLS TREE DECORATION', 'RED RETROSPOT OVEN GLOVE', 'RED RETROSPOT PEG BAG', 'MOODY GIRL DOOR HANGER', 'HOME SWEET HOME METAL SIGN', 'BEWARE OF THE CAT METAL SIGN', 'COOK WITH WINE METAL SIGN', 'PARTY METAL SIGN', 'POTTERING IN THE SHED METAL SIGN', 'GIN + TONIC DIET METAL SIGN', 'PLEASE ONE PERSON METAL SIGN', 'WHITE BELL HONEYCOMB PAPER', 'MULTICOLOUR  CONFETTI IN TUBE', 'SET OF 72 RETROSPOT PAPER  DOILIES', 'PACK OF 72 RETROSPOT CAKE CASES', 'PACK OF 72 SKULL CAKE CASES', 'SET 3 RETROSPOT TEA,COFFEE,SUGAR', 'RED RETROSPOT ROUND CAKE TINS', 'SET/4 BADGES DOGS', 'SET/4 BADGES CUTE CREATURES', 'SET/4 SKULL BADGES', 'SWEETHEART CERAMIC TRINKET BOX', 'STRAWBERRY CERAMIC TRINKET POT', 'RED RETROSPOT PLATE', 'DOOR HANGER  MUM + DADS ROOM', 'WOODLAND  HEIGHT CHART STICKERS', 'VICTORIAN SEWING BOX MEDIUM', 'VICTORIAN SEWING BOX LARGE', 'FIRST AID TIN', 'STRIPEY CHOCOLATE NESTING BOXES', 'GLASS HEART T-LIGHT HOLDER', 'SMALL GLASS HEART TRINKET POT', 'AGED GLASS SILVER T-LIGHT HOLDER', 'BALLOONS  WRITING SET', 'DINOSAURS  WRITING SET', 'EUCALYPTUS & PINECONE  WREATH', 'TOAST ITS - FAIRY FLOWER', 'TOAST ITS - HAPPY BIRTHDAY', 'MIRRORED WALL ART PHOTO FRAMES', 'SMALL CAMPHOR WOOD FIELD  MUSHROOM', 'SMALL TALL CAMPHOR WOOD TOADSTOOL', 'CAMPHOR WOOD PORTOBELLO MUSHROOM', 'WOODEN HAPPY BIRTHDAY GARLAND', 'MINI WOODEN H ...

# %% [markdown]
# #### Store (only items) transaction data into a .csv file.

# %%
df2 = pd.DataFrame(transactions)
df2.to_csv('transactions.csv')
df2.head()
# Out:
#                                  0                            1     \
# 0  WHITE HANGING HEART T-LIGHT HOLDER          WHITE METAL LANTERN
# 1              HAND WARMER UNION JACK    HAND WARMER RED POLKA DOT
# 2       ASSORTED COLOUR BIRD ORNAMENT    POPPY'S PLAYHOUSE BEDROOM
# 3            JAM MAKING SET WITH JARS  RED COAT RACK PARIS FASHION
# 4            BATH BUILDING BLOCK WORD                         None
#
#                              2                                    3     \
# 0  CREAM CUPID HEARTS COAT HANGER  KNITTED UNION FLAG HOT WATER BOTTLE
# 1                            None                                 None
# 2       POPPY'S PLAYHOUSE KITCHEN    FELTCRAFT PRINCESS CHARLOTTE DOLL
# 3  YELLOW COAT RACK PARIS FASHION         BLUE COAT RACK PARIS FASHION
# 4                            None                                 None
#
#                              4                                   5     \
# 0  RED WOOLLY HOTTIE WHITE HEART.        SET 7 BABUSHKA NESTING BOXES
# 1                            None                                None
# 2          IVORY KNITTED MUG COSY  BOX OF 6 ASSORTED COLOUR TEASPOONS
# 3                            None                                None
# 4                            None                                None
#
#                                 6                               7     \
# 0  GLASS STAR FROSTED T-LIGHT HOLDER                            None
# 1                               None                            None
# 2       BOX OF VINTAGE JIGSAW BLOCKS  BOX OF VINTAGE ALPHABET BLOCKS
# 3                               None                            None
# 4                               None                            None
#
#                        8                         9     ...  1104  1105  1106  \
# 0                      None                      None  ...  None  None  None
# 1                      None                      None  ...  None  None  None
# 2  HOME BUILDING BLOCK WORD  LOVE BUILDING BLOCK WORD  ...  None  None  None
# 3                      None                      None  ...  None  None  None
# 4                      None                      None  ...  None  None  None
#
#    1107  1108  1109  1110  1111  1112  1113
# 0  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None
#
# [5 rows x 1114 columns]

# %% [markdown]
# #### Display total number of transactions and items of transaction data.

# %%
print("Number of transactions: {}\nNumber of itmes: {}".format(len(df2),len(df)))
# Out:
# Number of transactions: 22106
# Number of itmes: 532621

# %% [markdown]
# #### Min Support as *0.001*, confidence as 0.8 and max length of 10

# %%
from apyori import apriori
rules = apriori( transactions , min_support = 0.01, min_confidence = 0.8, max_length = 10)

# %%
results = list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'GREEN REGENCY TEACUP AND SAUCER'}), support=0.02863475979372116, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.8263707571801566, lift=17.99778518051679)]),
#  RelationRecord(items=frozenset({'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE GREEN'}), support=0.012575771283814348, ordered_statistics=[OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE PINK'}), items_add=frozenset({'REGENCY TEA PLATE GREEN'}), confidence=0.9114754098360655, lift=52.88471236177444)]),
#  RelationRecord(items=frozenset({'REGENCY TEA PLATE GREEN', 'REGENCY TEA PLATE ROSES'}), support=0.014430471365240206, ordered_statistics=[OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE GREEN'}), items_add=frozenset({'REGENCY TEA PLATE ROSES'}), confidence=0.837270341207349, lift=41.592580140965524)]),
#  RelationRecord(items=frozenset({'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES'}), support=0.012168641997647698, ordered_statistics=[OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE PINK'}), items_add=frozenset({'REGENCY TEA PLATE ROSES'}), confidence=0.8819672131147541, lift=43.81296002947136)]),
#  RelationRecord(items=frozenset({'SET/6 RED SPOTTY PAPER CUPS', 'SET/6 RED SPOTTY PAPER PLATES'}), support=0.015832805573147563, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SET/6 RED SPOTTY PAPER CUPS'}), items_add=frozenset({'SET/6 RED SPOTTY PAPER PLATES'}), confidence=0.8177570093457944, lift=34.23737963749646)]),
#  RelationRecord(items=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN', 'WOODEN TREE CHRISTMAS SCANDINAVIAN'}), support=0.0127114810458699, ordered_statistics=[OrderedStatistic(items_base=frozenset({'WOODEN TREE CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), confidence=0.8313609467455622, lift=35.89465837647929)]),
#  RelationRecord(items=frozenset({'ALARM CLOCK BAKELIKE RED', 'ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE CHOCOLATE'}), support=0.01017823215416629, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE CHOCOLATE'}), items_add=frozenset({'ALARM CLOCK BAKELIKE RED'}), confidence=0.8122743682310469, lift=17.084811783173667)]),
#  RelationRecord(items=frozenset({'LUNCH BAG  BLACK SKULL.', 'CHARLOTTE BAG PINK POLKADOT', 'RED RETROSPOT CHARLOTTE BAG'}), support=0.01013299556681444, ordered_statistics=[OrderedStatistic(items_base=frozenset({'LUNCH BAG  BLACK SKULL.', 'CHARLOTTE BAG PINK POLKADOT'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.8296296296296296, lift=17.736743319722045)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT'}), support=0.014656654301999457, ordered_statistics=[OrderedStatistic(items_base=frozenset({'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.8594164456233422, lift=18.3735589428913)]),
#  RelationRecord(items=frozenset({'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'WOODLAND CHARLOTTE BAG'}), support=0.014611417714647607, ordered_statistics=[OrderedStatistic(items_base=frozenset({'WOODLAND CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.821882951653944, lift=17.571126237197376)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG SUKI DESIGN'}), support=0.015018547000814259, ordered_statistics=[OrderedStatistic(items_base=frozenset({'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG SUKI DESIGN'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.8038740920096852, lift=17.186112841359865)]),
#  RelationRecord(items=frozenset({'GREEN REGENCY TEACUP AND SAUCER', 'JUMBO BAG RED RETROSPOT', 'DOTCOM POSTAGE'}), support=0.01026870532886999, ordered_statistics=[OrderedStatistic(items_base=frozenset({'GREEN REGENCY TEACUP AND SAUCER', 'JUMBO BAG RED RETROSPOT'}), items_add=frozenset({'DOTCOM POSTAGE'}), confidence=0.8407407407407407, lift=26.25058589663109)]),
#  RelationRecord(items=frozenset({'GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER', 'DOTCOM POSTAGE'}), support=0.010540124852981092, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ROSES REGENCY TEACUP AND SAUCER', 'DOTCOM POSTAGE'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.8118466898954705, lift=17.681461011654452)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT', 'DOTCOM POSTAGE'}), support=0.012530534696462498, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'DOTCOM POSTAGE'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8028985507246377, lift=8.484166043173442)]),
#  RelationRecord(items=frozenset({'JUMBO BAG RED RETROSPOT', 'SUKI  SHOULDER BAG', 'DOTCOM POSTAGE'}), support=0.011218673663258844, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG RED RETROSPOT', 'SUKI  SHOULDER BAG'}), items_add=frozenset({'DOTCOM POSTAGE'}), confidence=0.8825622775800711, lift=27.55638659348171)]),
#  RelationRecord(items=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), support=0.01551614946168461, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.8749999999999999, lift=19.056896551724133)]),
#  RelationRecord(items=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER'}), support=0.024518230344702796, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'GREEN REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'ROSES REGENCY TEACUP AND SAUCER'}), confidence=0.8562401263823065, lift=17.756139056104377), OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.9048414023372287, lift=19.706821714351502)]),
#  RelationRecord(items=frozenset({'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER', 'ROSES REGENCY TEACUP AND SAUCER'}), support=0.01845652763955487, ordered_statistics=[OrderedStatistic(items_base=frozenset({'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), items_add=frozenset({'ROSES REGENCY TEACUP AND SAUCER'}), confidence=0.8015717092337917, lift=16.622461730133395)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG SCANDINAVIAN BLUE PAISLEY'}), support=0.012123405410295848, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG SCANDINAVIAN BLUE PAISLEY'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8427672955974843, lift=8.905455944779153)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY'}), support=0.0126210078711662, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG STRAWBERRY'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8017241379310345, lift=8.471756115250214)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG TOYS'}), support=0.010540124852981092, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG TOYS'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8262411347517731, lift=8.730825298672416)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY'}), support=0.017099430018999367, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8076923076923077, lift=8.534821297249595)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'RECYCLING BAG RETROSPOT', 'JUMBO BAG RED RETROSPOT'}), support=0.010992490726499594, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'RECYCLING BAG RETROSPOT'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8127090301003346, lift=8.587832609654873)]),
#  RelationRecord(items=frozenset({'JUMBO STORAGE BAG SUKI', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG SCANDINAVIAN BLUE PAISLEY'}), support=0.010992490726499594, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO STORAGE BAG SUKI', 'JUMBO BAG SCANDINAVIAN BLUE PAISLEY'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8046357615894041, lift=8.502523014194725)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CHARLOTTE BAG', 'LUNCH BAG  BLACK SKULL.', 'RED RETROSPOT CHARLOTTE BAG'}), support=0.01017823215416629, ordered_statistics=[OrderedStatistic(items_base=frozenset({'STRAWBERRY CHARLOTTE BAG', 'LUNCH BAG  BLACK SKULL.'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.800711743772242, lift=17.118504649738085)]),
#  RelationRecord(items=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), support=0.014973310413462408, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), items_add=frozenset({'ROSES REGENCY TEACUP AND SAUCER'}), confidence=0.8443877551020408, lift=17.51035245242562)]),
#  RelationRecord(items=frozenset({"POPPY'S PLAYHOUSE LIVINGROOM", "POPPY'S PLAYHOUSE KITCHEN", "POPPY'S PLAYHOUSE BEDROOM"}), support=0.01013299556681444, ordered_statistics=[OrderedStatistic(items_base=frozenset({"POPPY'S PLAYHOUSE LIVINGROOM", "POPPY'S PLAYHOUSE BEDROOM"}), items_add=frozenset({"POPPY'S PLAYHOUSE KITCHEN"}), confidence=0.8615384615384616, lift=43.581622953705335), OrderedStatistic(items_base=frozenset({"POPPY'S PLAYHOUSE LIVINGROOM", "POPPY'S PLAYHOUSE KITCHEN"}), items_add=frozenset({"POPPY'S PLAYHOUSE BEDROOM"}), confidence=0.8549618320610687, lift=44.680345767238734)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'WOODLAND CHARLOTTE BAG'}), support=0.014792364064055008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'STRAWBERRY CHARLOTTE BAG', 'WOODLAND CHARLOTTE BAG'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.8054187192118227, lift=17.219135596611753)]),
#  RelationRecord(items=frozenset({'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE GREEN', 'REGENCY TEA PLATE ROSES'}), support=0.011535329774721796, ordered_statistics=[OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE PINK'}), items_add=frozenset({'REGENCY TEA PLATE GREEN', 'REGENCY TEA PLATE ROSES'}), confidence=0.8360655737704918, lift=57.937509635644176), OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE GREEN'}), items_add=frozenset({'REGENCY TEA PLATE ROSES'}), confidence=0.9172661870503598, lift=45.56648613693316), OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES'}), items_add=frozenset({'REGENCY TEA PLATE GREEN'}), confidence=0.9479553903345725, lift=55.00131721453034)]),
#  RelationRecord(items=frozenset({'SET/6 RED SPOTTY PAPER CUPS', 'SET/6 RED SPOTTY PAPER PLATES', 'SET/20 RED RETROSPOT PAPER NAPKINS'}), support=0.011987695648240296, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SET/6 RED SPOTTY PAPER CUPS', 'SET/20 RED RETROSPOT PAPER NAPKINS'}), items_add=frozenset({'SET/6 RED SPOTTY PAPER PLATES'}), confidence=0.8952702702702702, lift=37.48266021703522)]),
#  RelationRecord(items=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN', 'WOODEN STAR CHRISTMAS SCANDINAVIAN', 'WOODEN TREE CHRISTMAS SCANDINAVIAN'}), support=0.01044965167827739, ordered_statistics=[OrderedStatistic(items_base=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN', 'WOODEN TREE CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), confidence=0.9277108433734939, lift=40.05464043674698), OrderedStatistic(items_base=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN', 'WOODEN TREE CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN'}), confidence=0.8220640569395017, lift=33.77797033959967)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'CHARLOTTE BAG SUKI DESIGN'}), support=0.010992490726499594, ordered_statistics=[OrderedStatistic(items_base=frozenset({'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'CHARLOTTE BAG SUKI DESIGN'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.9033457249070632, lift=19.31272784796474)]),
#  RelationRecord(items=frozenset({'WOODLAND CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'CHARLOTTE BAG SUKI DESIGN'}), support=0.011263910250610694, ordered_statistics=[OrderedStatistic(items_base=frozenset({'WOODLAND CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'CHARLOTTE BAG SUKI DESIGN'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.8586206896551725, lift=18.35654638831455)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'WOODLAND CHARLOTTE BAG'}), support=0.010856780964444042, ordered_statistics=[OrderedStatistic(items_base=frozenset({'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'WOODLAND CHARLOTTE BAG'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.9195402298850575, lift=19.658951955356944)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG SUKI DESIGN', 'WOODLAND CHARLOTTE BAG'}), support=0.011671039536777346, ordered_statistics=[OrderedStatistic(items_base=frozenset({'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG SUKI DESIGN', 'WOODLAND CHARLOTTE BAG'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.8571428571428572, lift=18.324951644100583)]),
#  RelationRecord(items=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER', 'ROSES REGENCY TEACUP AND SAUCER'}), support=0.013616212792906902, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), items_add=frozenset({'ROSES REGENCY TEACUP AND SAUCER'}), confidence=0.8775510204081632, lift=18.198070222460466), OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.9093655589123867, lift=19.805354724450464)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO STORAGE BAG SUKI', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG WOODLAND ANIMALS'}), support=0.010585361440332942, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO STORAGE BAG SUKI', 'JUMBO BAG WOODLAND ANIMALS'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8417266187050361, lift=8.894459193639353)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO STORAGE BAG SUKI', 'JUMBO BAG RED RETROSPOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY'}), support=0.012123405410295848, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO STORAGE BAG SUKI', 'JUMBO SHOPPER VINTAGE RED PAISLEY'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8673139158576052, lift=9.164838156763011)]),
#  RelationRecord(items=frozenset({'JUMBO BAG WOODLAND ANIMALS', 'JUMBO STORAGE BAG SUKI', 'JUMBO BAG RED RETROSPOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY'}), support=0.01004252239211074, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG WOODLAND ANIMALS', 'JUMBO STORAGE BAG SUKI', 'JUMBO SHOPPER VINTAGE RED PAISLEY'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8072727272727274, lift=8.530387623848428)])]

# %%
print("There are {} RULES derived.".format(len(results)))
# Out:
# There are 39 RULES derived.

# %% [markdown]
# #### Print only top 10 rules in following format

# %%
for i in  range(10):
  item = results[i] 
  pair=item[0]
  #print(pair)
  items=[x for x in pair]
  #print (items)
  print(items[0]+'->'+items[1])
  # second index of the inner list
  print("Support: " + str(item[1]))
  # third index of the list located at 0th
  # of the third index of the inner list

  print("Confidence: " + str(item[2][0][2]))
  print("Lift: " + str(item[2][0][3]))
  print("==============",i+1,"=================")
# Out:
# PINK REGENCY TEACUP AND SAUCER->GREEN REGENCY TEACUP AND SAUCER
# Support: 0.02863475979372116
# Confidence: 0.8263707571801566
# Lift: 17.99778518051679
# ============== 1 =================
# REGENCY TEA PLATE PINK->REGENCY TEA PLATE GREEN
# Support: 0.012575771283814348
# Confidence: 0.9114754098360655
# Lift: 52.88471236177444
# ============== 2 =================
# REGENCY TEA PLATE GREEN->REGENCY TEA PLATE ROSES
# Support: 0.014430471365240206
# Confidence: 0.837270341207349
# Lift: 41.592580140965524
# ============== 3 =================
# REGENCY TEA PLATE PINK->REGENCY TEA PLATE ROSES
# Support: 0.012168641997647698
# Confidence: 0.8819672131147541
# Lift: 43.81296002947136
# ============== 4 =================
# SET/6 RED SPOTTY PAPER CUPS->SET/6 RED SPOTTY PAPER PLATES
# Support: 0.015832805573147563
# Confidence: 0.8177570093457944
# Lift: 34.23737963749646
# ============== 5 =================
# WOODEN STAR CHRISTMAS SCANDINAVIAN->WOODEN TREE CHRISTMAS SCANDINAVIAN
# Support: 0.0127114810458699
# Confidence: 0.8313609467455622
# Lift: 35.89465837647929
# ============== 6 =================
# ALARM CLOCK BAKELIKE RED->ALARM CLOCK BAKELIKE GREEN
# Support: 0.01017823215416629
# Confidence: 0.8122743682310469
# Lift: 17.084811783173667
# ============== 7 =================
# LUNCH BAG  BLACK SKULL.->CHARLOTTE BAG PINK POLKADOT
# Support: 0.01013299556681444
# Confidence: 0.8296296296296296
# Lift: 17.736743319722045
# ============== 8 =================
# STRAWBERRY CHARLOTTE BAG->RED RETROSPOT CHARLOTTE BAG
# Support: 0.014656654301999457
# Confidence: 0.8594164456233422
# Lift: 18.3735589428913
# ============== 9 =================
# RED RETROSPOT CHARLOTTE BAG->CHARLOTTE BAG PINK POLKADOT
# Support: 0.014611417714647607
# Confidence: 0.821882951653944
# Lift: 17.571126237197376
# ============== 10 =================

# %% [markdown]
# #### Get all rules with 100% confidence

# %%
rules = apriori( transactions ,  min_confidence = 1)

# %%
results = list(rules)

# %%
print("There are {} RULES derived.".format(len(results)))
# Out:
# There are 0 RULES derived.

# %% [markdown]
# #### Get rules with max length of 3

# %%
rules = apriori( transactions , max_length = 3)

# %%
results = list(rules)
print("There are {} RULES derived.".format(len(results)))
# Out:
# There are 1 RULES derived.

# %%
def inspect(results):
    lhs = [tuple(result[2][0][0])[0] for result in results]
    rhs = [tuple(result[2][0][1])[0] for result in results]
    supports = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

# %%
from apyori import apriori
rules = apriori( transactions , min_support = 0.01, min_confidence = 0.8, max_length = 10)
results = list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'GREEN REGENCY TEACUP AND SAUCER'}), support=0.02863475979372116, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.8263707571801566, lift=17.99778518051679)]),
#  RelationRecord(items=frozenset({'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE GREEN'}), support=0.012575771283814348, ordered_statistics=[OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE PINK'}), items_add=frozenset({'REGENCY TEA PLATE GREEN'}), confidence=0.9114754098360655, lift=52.88471236177444)]),
#  RelationRecord(items=frozenset({'REGENCY TEA PLATE GREEN', 'REGENCY TEA PLATE ROSES'}), support=0.014430471365240206, ordered_statistics=[OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE GREEN'}), items_add=frozenset({'REGENCY TEA PLATE ROSES'}), confidence=0.837270341207349, lift=41.592580140965524)]),
#  RelationRecord(items=frozenset({'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES'}), support=0.012168641997647698, ordered_statistics=[OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE PINK'}), items_add=frozenset({'REGENCY TEA PLATE ROSES'}), confidence=0.8819672131147541, lift=43.81296002947136)]),
#  RelationRecord(items=frozenset({'SET/6 RED SPOTTY PAPER CUPS', 'SET/6 RED SPOTTY PAPER PLATES'}), support=0.015832805573147563, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SET/6 RED SPOTTY PAPER CUPS'}), items_add=frozenset({'SET/6 RED SPOTTY PAPER PLATES'}), confidence=0.8177570093457944, lift=34.23737963749646)]),
#  RelationRecord(items=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN', 'WOODEN TREE CHRISTMAS SCANDINAVIAN'}), support=0.0127114810458699, ordered_statistics=[OrderedStatistic(items_base=frozenset({'WOODEN TREE CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), confidence=0.8313609467455622, lift=35.89465837647929)]),
#  RelationRecord(items=frozenset({'ALARM CLOCK BAKELIKE RED', 'ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE CHOCOLATE'}), support=0.01017823215416629, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE CHOCOLATE'}), items_add=frozenset({'ALARM CLOCK BAKELIKE RED'}), confidence=0.8122743682310469, lift=17.084811783173667)]),
#  RelationRecord(items=frozenset({'LUNCH BAG  BLACK SKULL.', 'CHARLOTTE BAG PINK POLKADOT', 'RED RETROSPOT CHARLOTTE BAG'}), support=0.01013299556681444, ordered_statistics=[OrderedStatistic(items_base=frozenset({'LUNCH BAG  BLACK SKULL.', 'CHARLOTTE BAG PINK POLKADOT'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.8296296296296296, lift=17.736743319722045)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT'}), support=0.014656654301999457, ordered_statistics=[OrderedStatistic(items_base=frozenset({'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.8594164456233422, lift=18.3735589428913)]),
#  RelationRecord(items=frozenset({'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'WOODLAND CHARLOTTE BAG'}), support=0.014611417714647607, ordered_statistics=[OrderedStatistic(items_base=frozenset({'WOODLAND CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.821882951653944, lift=17.571126237197376)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG SUKI DESIGN'}), support=0.015018547000814259, ordered_statistics=[OrderedStatistic(items_base=frozenset({'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG SUKI DESIGN'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.8038740920096852, lift=17.186112841359865)]),
#  RelationRecord(items=frozenset({'GREEN REGENCY TEACUP AND SAUCER', 'JUMBO BAG RED RETROSPOT', 'DOTCOM POSTAGE'}), support=0.01026870532886999, ordered_statistics=[OrderedStatistic(items_base=frozenset({'GREEN REGENCY TEACUP AND SAUCER', 'JUMBO BAG RED RETROSPOT'}), items_add=frozenset({'DOTCOM POSTAGE'}), confidence=0.8407407407407407, lift=26.25058589663109)]),
#  RelationRecord(items=frozenset({'GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER', 'DOTCOM POSTAGE'}), support=0.010540124852981092, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ROSES REGENCY TEACUP AND SAUCER', 'DOTCOM POSTAGE'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.8118466898954705, lift=17.681461011654452)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT', 'DOTCOM POSTAGE'}), support=0.012530534696462498, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'DOTCOM POSTAGE'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8028985507246377, lift=8.484166043173442)]),
#  RelationRecord(items=frozenset({'JUMBO BAG RED RETROSPOT', 'SUKI  SHOULDER BAG', 'DOTCOM POSTAGE'}), support=0.011218673663258844, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG RED RETROSPOT', 'SUKI  SHOULDER BAG'}), items_add=frozenset({'DOTCOM POSTAGE'}), confidence=0.8825622775800711, lift=27.55638659348171)]),
#  RelationRecord(items=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), support=0.01551614946168461, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.8749999999999999, lift=19.056896551724133)]),
#  RelationRecord(items=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER'}), support=0.024518230344702796, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'GREEN REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'ROSES REGENCY TEACUP AND SAUCER'}), confidence=0.8562401263823065, lift=17.756139056104377), OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.9048414023372287, lift=19.706821714351502)]),
#  RelationRecord(items=frozenset({'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER', 'ROSES REGENCY TEACUP AND SAUCER'}), support=0.01845652763955487, ordered_statistics=[OrderedStatistic(items_base=frozenset({'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), items_add=frozenset({'ROSES REGENCY TEACUP AND SAUCER'}), confidence=0.8015717092337917, lift=16.622461730133395)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG SCANDINAVIAN BLUE PAISLEY'}), support=0.012123405410295848, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG SCANDINAVIAN BLUE PAISLEY'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8427672955974843, lift=8.905455944779153)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY'}), support=0.0126210078711662, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG STRAWBERRY'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8017241379310345, lift=8.471756115250214)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG TOYS'}), support=0.010540124852981092, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG TOYS'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8262411347517731, lift=8.730825298672416)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY'}), support=0.017099430018999367, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8076923076923077, lift=8.534821297249595)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'RECYCLING BAG RETROSPOT', 'JUMBO BAG RED RETROSPOT'}), support=0.010992490726499594, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'RECYCLING BAG RETROSPOT'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8127090301003346, lift=8.587832609654873)]),
#  RelationRecord(items=frozenset({'JUMBO STORAGE BAG SUKI', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG SCANDINAVIAN BLUE PAISLEY'}), support=0.010992490726499594, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO STORAGE BAG SUKI', 'JUMBO BAG SCANDINAVIAN BLUE PAISLEY'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8046357615894041, lift=8.502523014194725)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CHARLOTTE BAG', 'LUNCH BAG  BLACK SKULL.', 'RED RETROSPOT CHARLOTTE BAG'}), support=0.01017823215416629, ordered_statistics=[OrderedStatistic(items_base=frozenset({'STRAWBERRY CHARLOTTE BAG', 'LUNCH BAG  BLACK SKULL.'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.800711743772242, lift=17.118504649738085)]),
#  RelationRecord(items=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), support=0.014973310413462408, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), items_add=frozenset({'ROSES REGENCY TEACUP AND SAUCER'}), confidence=0.8443877551020408, lift=17.51035245242562)]),
#  RelationRecord(items=frozenset({"POPPY'S PLAYHOUSE LIVINGROOM", "POPPY'S PLAYHOUSE KITCHEN", "POPPY'S PLAYHOUSE BEDROOM"}), support=0.01013299556681444, ordered_statistics=[OrderedStatistic(items_base=frozenset({"POPPY'S PLAYHOUSE LIVINGROOM", "POPPY'S PLAYHOUSE BEDROOM"}), items_add=frozenset({"POPPY'S PLAYHOUSE KITCHEN"}), confidence=0.8615384615384616, lift=43.581622953705335), OrderedStatistic(items_base=frozenset({"POPPY'S PLAYHOUSE LIVINGROOM", "POPPY'S PLAYHOUSE KITCHEN"}), items_add=frozenset({"POPPY'S PLAYHOUSE BEDROOM"}), confidence=0.8549618320610687, lift=44.680345767238734)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'WOODLAND CHARLOTTE BAG'}), support=0.014792364064055008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'STRAWBERRY CHARLOTTE BAG', 'WOODLAND CHARLOTTE BAG'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.8054187192118227, lift=17.219135596611753)]),
#  RelationRecord(items=frozenset({'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE GREEN', 'REGENCY TEA PLATE ROSES'}), support=0.011535329774721796, ordered_statistics=[OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE PINK'}), items_add=frozenset({'REGENCY TEA PLATE GREEN', 'REGENCY TEA PLATE ROSES'}), confidence=0.8360655737704918, lift=57.937509635644176), OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE GREEN'}), items_add=frozenset({'REGENCY TEA PLATE ROSES'}), confidence=0.9172661870503598, lift=45.56648613693316), OrderedStatistic(items_base=frozenset({'REGENCY TEA PLATE PINK', 'REGENCY TEA PLATE ROSES'}), items_add=frozenset({'REGENCY TEA PLATE GREEN'}), confidence=0.9479553903345725, lift=55.00131721453034)]),
#  RelationRecord(items=frozenset({'SET/6 RED SPOTTY PAPER CUPS', 'SET/6 RED SPOTTY PAPER PLATES', 'SET/20 RED RETROSPOT PAPER NAPKINS'}), support=0.011987695648240296, ordered_statistics=[OrderedStatistic(items_base=frozenset({'SET/6 RED SPOTTY PAPER CUPS', 'SET/20 RED RETROSPOT PAPER NAPKINS'}), items_add=frozenset({'SET/6 RED SPOTTY PAPER PLATES'}), confidence=0.8952702702702702, lift=37.48266021703522)]),
#  RelationRecord(items=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN', 'WOODEN STAR CHRISTMAS SCANDINAVIAN', 'WOODEN TREE CHRISTMAS SCANDINAVIAN'}), support=0.01044965167827739, ordered_statistics=[OrderedStatistic(items_base=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN', 'WOODEN TREE CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN'}), confidence=0.9277108433734939, lift=40.05464043674698), OrderedStatistic(items_base=frozenset({'WOODEN STAR CHRISTMAS SCANDINAVIAN', 'WOODEN TREE CHRISTMAS SCANDINAVIAN'}), items_add=frozenset({'WOODEN HEART CHRISTMAS SCANDINAVIAN'}), confidence=0.8220640569395017, lift=33.77797033959967)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'CHARLOTTE BAG SUKI DESIGN'}), support=0.010992490726499594, ordered_statistics=[OrderedStatistic(items_base=frozenset({'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'CHARLOTTE BAG SUKI DESIGN'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.9033457249070632, lift=19.31272784796474)]),
#  RelationRecord(items=frozenset({'WOODLAND CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'CHARLOTTE BAG SUKI DESIGN'}), support=0.011263910250610694, ordered_statistics=[OrderedStatistic(items_base=frozenset({'WOODLAND CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'CHARLOTTE BAG SUKI DESIGN'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.8586206896551725, lift=18.35654638831455)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'WOODLAND CHARLOTTE BAG'}), support=0.010856780964444042, ordered_statistics=[OrderedStatistic(items_base=frozenset({'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG PINK POLKADOT', 'WOODLAND CHARLOTTE BAG'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.9195402298850575, lift=19.658951955356944)]),
#  RelationRecord(items=frozenset({'STRAWBERRY CHARLOTTE BAG', 'RED RETROSPOT CHARLOTTE BAG', 'CHARLOTTE BAG SUKI DESIGN', 'WOODLAND CHARLOTTE BAG'}), support=0.011671039536777346, ordered_statistics=[OrderedStatistic(items_base=frozenset({'STRAWBERRY CHARLOTTE BAG', 'CHARLOTTE BAG SUKI DESIGN', 'WOODLAND CHARLOTTE BAG'}), items_add=frozenset({'RED RETROSPOT CHARLOTTE BAG'}), confidence=0.8571428571428572, lift=18.324951644100583)]),
#  RelationRecord(items=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER', 'ROSES REGENCY TEACUP AND SAUCER'}), support=0.013616212792906902, ordered_statistics=[OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'GREEN REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), items_add=frozenset({'ROSES REGENCY TEACUP AND SAUCER'}), confidence=0.8775510204081632, lift=18.198070222460466), OrderedStatistic(items_base=frozenset({'PINK REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER', 'REGENCY CAKESTAND 3 TIER'}), items_add=frozenset({'GREEN REGENCY TEACUP AND SAUCER'}), confidence=0.9093655589123867, lift=19.805354724450464)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO STORAGE BAG SUKI', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG WOODLAND ANIMALS'}), support=0.010585361440332942, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO STORAGE BAG SUKI', 'JUMBO BAG WOODLAND ANIMALS'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8417266187050361, lift=8.894459193639353)]),
#  RelationRecord(items=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO STORAGE BAG SUKI', 'JUMBO BAG RED RETROSPOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY'}), support=0.012123405410295848, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG PINK POLKADOT', 'JUMBO STORAGE BAG SUKI', 'JUMBO SHOPPER VINTAGE RED PAISLEY'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8673139158576052, lift=9.164838156763011)]),
#  RelationRecord(items=frozenset({'JUMBO BAG WOODLAND ANIMALS', 'JUMBO STORAGE BAG SUKI', 'JUMBO BAG RED RETROSPOT', 'JUMBO SHOPPER VINTAGE RED PAISLEY'}), support=0.01004252239211074, ordered_statistics=[OrderedStatistic(items_base=frozenset({'JUMBO BAG WOODLAND ANIMALS', 'JUMBO STORAGE BAG SUKI', 'JUMBO SHOPPER VINTAGE RED PAISLEY'}), items_add=frozenset({'JUMBO BAG RED RETROSPOT'}), confidence=0.8072727272727274, lift=8.530387623848428)])]

# %% [markdown]
# #### Find what customers buy before buying 'METAL'

# %%
resultsinDataFrame = pd.DataFrame(inspect(results), columns =['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence','Lift'])
"""## Displaying the results non sorted"""
a = resultsinDataFrame[resultsinDataFrame['Left Hand Side']=='METAL']
# Out:
# Empty DataFrame
# Columns: [Left Hand Side, Right Hand Side, Support, Confidence, Lift]
# Index: []

# %% [markdown]
# #### Find the answer to the question Customers who bought METAL also bought

# %%
resultsinDataFrame[resultsinDataFrame['Right Hand Side'].str.contains('METAL')]
# Out:
# Empty DataFrame
# Columns: [Left Hand Side, Right Hand Side, Support, Confidence, Lift]
# Index: []

# %%
resultsinDataFrame
# Out:
#                          Left Hand Side                     Right Hand Side  \
# 0        PINK REGENCY TEACUP AND SAUCER     GREEN REGENCY TEACUP AND SAUCER
# 1                REGENCY TEA PLATE PINK             REGENCY TEA PLATE GREEN
# 2               REGENCY TEA PLATE GREEN             REGENCY TEA PLATE ROSES
# 3                REGENCY TEA PLATE PINK             REGENCY TEA PLATE ROSES
# 4           SET/6 RED SPOTTY PAPER CUPS       SET/6 RED SPOTTY PAPER PLATES
# 5    WOODEN TREE CHRISTMAS SCANDINAVIAN  WOODEN STAR CHRISTMAS SCANDINAVIAN
# 6            ALARM CLOCK BAKELIKE GREEN            ALARM CLOCK BAKELIKE RED
# 7           CHARLOTTE BAG PINK POLKADOT         RED RETROSPOT CHARLOTTE BAG
# 8           CHARLOTTE BAG PINK POLKADOT         RED RETROSPOT CHARLOTTE BAG
# 9           CHARLOTTE BAG PINK POLKADOT         RED RETROSPOT CHARLOTTE BAG
# 10             STRAWBERRY CHARLOTTE BAG         RED RETROSPOT CHARLOTTE BAG
# 11      GREEN REGENCY TEACUP AND SAUCER                      DOTCOM POSTAGE
# 12      ROSES REGENCY TEACUP AND SAUCER     GREEN REGENCY TEACUP AND SAUCER
# 13                       DOTCOM POSTAGE             JUMBO BAG RED RETROSPOT
# 14                   SUKI  SHOULDER BAG                      DOTCOM POSTAGE
# 15             REGENCY CAKESTAND 3 TIER     GREEN REGENCY TEACUP AND SAUCER
# 16       PINK REGENCY TEACUP AND SAUCER     ROSES REGENCY TEACUP AND SAUCER
# 17             REGENCY CAKESTAND 3 TIER     ROSES REGENCY TEACUP AND SAUCER
# 18  JUMBO BAG SCANDINAVIAN BLUE PAISLEY             JUMBO BAG RED RETROSPOT
# 19              JUMBO BAG PINK POLKADOT             JUMBO BAG RED RETROSPOT
# 20                       JUMBO BAG TOYS             JUMBO BAG RED RETROSPOT
# 21    JUMBO SHOPPER VINTAGE RED PAISLEY             JUMBO BAG RED RETROSPOT
# 22              RECYCLING BAG RETROSPOT             JUMBO BAG RED RETROSPOT
# 23  JUMBO BAG SCANDINAVIAN BLUE PAISLEY             JUMBO BAG RED RETROSPOT
# 24             STRAWBERRY CHARLOTTE BAG         RED RETROSPOT CHARLOTTE BAG
# 25             REGENCY CAKESTAND 3 TIER     ROSES REGENCY TEACUP AND SAUCER
# 26         POPPY'S PLAYHOUSE LIVINGROOM           POPPY'S PLAYHOUSE KITCHEN
# 27             STRAWBERRY CHARLOTTE BAG         RED RETROSPOT CHARLOTTE BAG
# 28               REGENCY TEA PLATE PINK             REGENCY TEA PLATE GREEN
# 29   SET/20 RED RETROSPOT PAPER NAPKINS       SET/6 RED SPOTTY PAPER PLATES
# 30  WOODEN HEART CHRISTMAS SCANDINAVIAN  WOODEN STAR CHRISTMAS SCANDINAVIAN
# 31          CHARLOTTE BAG PINK POLKADOT         RED RETROSPOT CHARLOTTE BAG
# 32          CHARLOTTE BAG PINK POLKADOT         RED RETROSPOT CHARLOTTE BAG
# 33          CHARLOTTE BAG PINK POLKADOT         RED RETROSPOT CHARLOTTE BAG
# 34             STRAWBERRY CHARLOTTE BAG         RED RETROSPOT CHARLOTTE BAG
# 35             REGENCY CAKESTAND 3 TIER     ROSES REGENCY TEACUP AND SAUCER
# 36           JUMBO BAG WOODLAND ANIMALS             JUMBO BAG RED RETROSPOT
# 37    JUMBO SHOPPER VINTAGE RED PAISLEY             JUMBO BAG RED RETROSPOT
# 38    JUMBO SHOPPER VINTAGE RED PAISLEY             JUMBO BAG RED RETROSPOT
#
#      Support  Confidence       Lift
# 0   0.028635    0.826371  17.997785
# 1   0.012576    0.911475  52.884712
# 2   0.014430    0.837270  41.592580
# 3   0.012169    0.881967  43.812960
# 4   0.015833    0.817757  34.237380
# 5   0.012711    0.831361  35.894658
# 6   0.010178    0.812274  17.084812
# 7   0.010133    0.829630  17.736743
# 8   0.014657    0.859416  18.373559
# 9   0.014611    0.821883  17.571126
# 10  0.015019    0.803874  17.186113
# 11  0.010269    0.840741  26.250586
# 12  0.010540    0.811847  17.681461
# 13  0.012531    0.802899   8.484166
# 14  0.011219    0.882562  27.556387
# 15  0.015516    0.875000  19.056897
# 16  0.024518    0.856240  17.756139
# 17  0.018457    0.801572  16.622462
# 18  0.012123    0.842767   8.905456
# 19  0.012621    0.801724   8.471756
# 20  0.010540    0.826241   8.730825
# 21  0.017099    0.807692   8.534821
# 22  0.010992    0.812709   8.587833
# 23  0.010992    0.804636   8.502523
# 24  0.010178    0.800712  17.118505
# 25  0.014973    0.844388  17.510352
# 26  0.010133    0.861538  43.581623
# 27  0.014792    0.805419  17.219136
# 28  0.011535    0.836066  57.937510
# 29  0.011988    0.895270  37.482660
# 30  0.010450    0.927711  40.054640
# 31  0.010992    0.903346  19.312728
# 32  0.011264    0.858621  18.356546
# 33  0.010857    0.919540  19.658952
# 34  0.011671    0.857143  18.324952
# 35  0.013616    0.877551  18.198070
# 36  0.010585    0.841727   8.894459
# 37  0.012123    0.867314   9.164838
# 38  0.010043    0.807273   8.530388
